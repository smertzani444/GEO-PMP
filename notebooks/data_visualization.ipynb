# %%
import matplotlib.pyplot as plt

# %%
# assuming column name is "IBS" with values {0,1}
counts = df["IBS"].value_counts().sort_index()

labels = ["non-IBS", "IBS"]
values = counts.values

plt.figure()
plt.bar(labels, values)
plt.ylabel("Number of residues")
plt.title("Class distribution: IBS vs non-IBS")
plt.show()
