# %% [markdown]
# # Imports

# %%
# %run setup.py

# %%
import pandas as pd
import numpy as np
import joblib
from pathlib import Path
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import lightgbm as lgb

from sklearn.metrics import average_precision_score, roc_auc_score, f1_score, precision_recall_curve, auc

from typing import List, Tuple
import optuna

from thesis_code.data_analysis.ml_pipeline import (
    load_parquet,
    load_multiple_parquets,
    protein_level_split,
    preprocess,
    calculate_class_weights,
    train_model,
    evaluate_model,
    save_model,
    load_model
    )

RANDOM_STATE = 42

# %% [markdown]
# # Load Data

# %%
df_full = load_parquet("/home/user_stel/project_thesis/data/derived/df_feat_context_v1.parquet")
df_surface = load_parquet("/home/user_stel/project_thesis/data/derived/df_ml_context_v1.parquet")

print(df_full.shape)
print(df_surface.shape)
# Out:
# (183890, 43)
# (106100, 43)

# %% [markdown]
# ## Sanity Checks

# %%
def check_dataset(
    df: pd.DataFrame,
    target_col: str = "IBS",
    required_cols: List[str] | None = None
):
    """
    Basic sanity checks for ML datasets.

    Parameters
    ----------
    df : pd.DataFrame
    target_col : str
    required_cols : list, optional
    """

    if target_col not in df.columns:
        raise ValueError(f"Target column '{target_col}' not found")

    if required_cols is not None:
        missing = set(required_cols) - set(df.columns)
        if missing:
            raise ValueError(f"Missing required columns: {missing}")

    if df[target_col].isna().any():
        raise ValueError("Target column contains NaNs")

    print("Dataset check passed:")
    print(f"  Samples: {len(df):,}")
    print(f"  IBS positives: {df[target_col].sum():,}")
    print(f"  IBS ratio: {df[target_col].mean():.4f}")

# %%
print("Full-surface IBS ratio:", df_full["IBS"].mean())
print("Surface-only IBS ratio:", df_surface["IBS"].mean())

df_full["IBS"].value_counts()
# Out:
# Full-surface IBS ratio: 0.1516286910653108
# Surface-only IBS ratio: 0.20555136663524975
# IBS
# False    156007
# True      27883
# Name: count, dtype: int64

# %% [markdown]
# # Split train/test/val

# %%
# Step 1: inspect
for i, col in enumerate(df_full.columns):
    print(f"{i:2d}  {col}")

# Step 2: decide
DROP_COLS = [
    "IBS",
    "domain",
    "cathpdb",
    "pdb",
    "uniprot_acc",
    "uniprot_id",
    "domain",
    "residue_name",
    "chain_id",
    "residue_number",
    "Experimental Method",
    "origin",
    "location",
    "taxon",
    "data_type",
    "resolution",
    "S35", "S60", "S95", "S100",
    "uniref50", "uniref90", "uniref100",
    "neighboursList",
    "neighbors"
]
# Out:
#  0  domain
#  1  cathpdb
#  2  pdb
#  3  uniprot_acc
#  4  uniprot_id
#  5  residue_name
#  6  IBS
#  7  chain_id
#  8  residue_number
#  9  b_factor
# 10  sec_struc
# 11  sec_struc_full
# 12  prot_block
# 13  data_type
# 14  Experimental Method
# 15  resolution
# 16  RSA_total_freesasa_tien
# 17  convhull_vertex
# 18  protrusion
# 19  is_hydrophobic_protrusion
# 20  is_co_insertable
# 21  neighboursList
# 22  density
# 23  exposed
# 24  S35
# 25  S60
# 26  S95
# 27  S100
# 28  uniref50
# 29  uniref90
# 30  uniref100
# 31  origin
# 32  location
# 33  taxon
# 34  neighbors
# 35  n_neighbors
# 36  neighbor_frac_exposed
# 37  neighbor_frac_hydrophobic
# 38  neighbor_frac_charged
# 39  neighbor_frac_polar
# 40  neighbor_frac_aromatic
# 41  neighbor_frac_small
# 42  neighbor_mean_RSA

# %%
df_full = df_full.reset_index(drop=True)
df_surface = df_surface.reset_index(drop=True)

# %%
train_prot, val_prot, test_prot = protein_level_split(df_full, "cathpdb")

df_train = df_full[df_full["cathpdb"].isin(train_prot)]
df_val   = df_full[df_full["cathpdb"].isin(val_prot)]
df_test  = df_full[df_full["cathpdb"].isin(test_prot)]

# %% [markdown]
# # Preprocessing

# %%
X_train, y_train = preprocess(
    df_train,
    target_col="IBS",
    drop_cols=DROP_COLS
)

X_val, y_val = preprocess(
    df_val,
    target_col="IBS",
    drop_cols=DROP_COLS
)

X_test, y_test = preprocess(
    df_test,
    target_col="IBS",
    drop_cols=DROP_COLS
)

# %% [markdown]
# # Hyperparameter Tuning

# %%
categorical_cols = X_train.select_dtypes(include="object").columns.tolist()
numeric_cols = X_train.select_dtypes(include=np.number).columns.tolist()

# %%
print(X_train.dtypes)
# Out:
# b_factor                     float64
# sec_struc                     object
# sec_struc_full                object
# prot_block                    object
# RSA_total_freesasa_tien      float64
# convhull_vertex                 bool
# protrusion                      bool
# is_hydrophobic_protrusion       bool
# is_co_insertable                bool
# density                        int64
# exposed                         bool
# n_neighbors                  float64
# neighbor_frac_exposed        float64
# neighbor_frac_hydrophobic    float64
# neighbor_frac_charged        float64
# neighbor_frac_polar          float64
# neighbor_frac_aromatic       float64
# neighbor_frac_small          float64
# neighbor_mean_RSA            float64
# dtype: object

# %% [markdown]
# ### Random Forest

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_cols),
        ("cat", OneHotEncoder(
            handle_unknown="ignore",
            sparse_output=False
        ), categorical_cols)
    ]
)

rf_pipeline = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("model", RandomForestClassifier(
            random_state=RANDOM_STATE,
            n_jobs=-1
        ))
    ]
)

# %%
def rf_objective(trial):

    params = {
        "model__n_estimators": trial.suggest_int("model__n_estimators", 300, 800),
        "model__max_depth": trial.suggest_int("model__max_depth", 5, 18),
        "model__min_samples_split": trial.suggest_int("model__min_samples_split", 5, 20),
        "model__min_samples_leaf": trial.suggest_int("model__min_samples_leaf", 5, 20),
        "model__max_features": trial.suggest_categorical(
            "model__max_features", ["sqrt", "log2"]
        )
    }

    model = rf_pipeline.set_params(**params)

    # Tune positive-class importance
    pos_scale = trial.suggest_float("pos_scale", 0.5, 2.0)
    class_weights = calculate_class_weights(y_train, pos_scale=pos_scale)
    model.set_params(model__class_weight=class_weights)

    model.fit(X_train, y_train)

    y_val_proba = model.predict_proba(X_val)[:, 1]
    return average_precision_score(y_val, y_val_proba)

# %%
study_rf = optuna.create_study(direction="maximize")
study_rf.optimize(rf_objective, n_trials=25)
# Out:
# [I 2026-02-10 20:38:24,890] A new study created in memory with name: no-name-12c4bf12-d325-4995-b4a2-1fc6dbb1f7af
# [I 2026-02-10 20:39:02,200] Trial 0 finished with value: 0.3416985751541191 and parameters: {'model__n_estimators': 619, 'model__max_depth': 9, 'model__min_samples_split': 12, 'model__min_samples_leaf': 8, 'model__max_features': 'sqrt', 'pos_scale': 1.6544023636914618}. Best is trial 0 with value: 0.3416985751541191.
# [I 2026-02-10 20:39:41,755] Trial 1 finished with value: 0.3763907837763151 and parameters: {'model__n_estimators': 624, 'model__max_depth': 15, 'model__min_samples_split': 6, 'model__min_samples_leaf': 9, 'model__max_features': 'log2', 'pos_scale': 1.9654197554955117}. Best is trial 1 with value: 0.3763907837763151.
# [I 2026-02-10 20:40:07,671] Trial 2 finished with value: 0.29404364528311017 and parameters: {'model__n_estimators': 729, 'model__max_depth': 5, 'model__min_samples_split': 15, 'model__min_samples_leaf': 19, 'model__max_features': 'sqrt', 'pos_scale': 1.159907103841523}. Best is trial 1 with value: 0.3763907837763151.
# [I 2026-02-10 20:40:47,795] Trial 3 finished with value: 0.3699672911894441 and parameters: {'model__n_estimators': 592, 'model__max_depth': 12, 'model__min_samples_split': 10, 'model__min_samples_leaf': 9, 'model__max_features': 'sqrt', 'pos_scale': 1.0599175257497953}. Best is trial 1 with value: 0.3763907837763151.
# [I 2026-02-10 20:41:38,366] Trial 4 finished with value: 0.36641543101276486 and parameters: {'model__n_estimators': 778, 'model__max_depth': 12, 'model__min_samples_split': 5, 'model__min_samples_leaf': 15, 'model__max_features': 'sqrt', 'pos_scale': 0.8068867190338462}. Best is trial 1 with value: 0.3763907837763151.
# [I 2026-02-10 20:48:51,937] Trial 5 finished with value: 0.29499674590708524 and parameters: {'model__n_estimators': 347, 'model__max_depth': 5, 'model__min_samples_split': 12, 'model__min_samples_leaf': 15, 'model__max_features': 'sqrt', 'pos_scale': 1.0249124655111197}. Best is trial 1 with value: 0.3763907837763151.
# [I 2026-02-10 20:49:19,330] Trial 6 finished with value: 0.3776768642866365 and parameters: {'model__n_estimators': 560, 'model__max_depth': 15, 'model__min_samples_split': 16, 'model__min_samples_leaf': 7, 'model__max_features': 'log2', 'pos_scale': 1.8010187788561296}. Best is trial 6 with value: 0.3776768642866365.
# [I 2026-02-10 20:49:31,539] Trial 7 finished with value: 0.3361582774687797 and parameters: {'model__n_estimators': 417, 'model__max_depth': 8, 'model__min_samples_split': 8, 'model__min_samples_leaf': 11, 'model__max_features': 'log2', 'pos_scale': 0.7096597605874906}. Best is trial 6 with value: 0.3776768642866365.
# [I 2026-02-10 20:49:43,691] Trial 8 finished with value: 0.35255168348232124 and parameters: {'model__n_estimators': 318, 'model__max_depth': 10, 'model__min_samples_split': 11, 'model__min_samples_leaf': 10, 'model__max_features': 'sqrt', 'pos_scale': 1.340771559912305}. Best is trial 6 with value: 0.3776768642866365.
# [I 2026-02-10 20:50:00,775] Trial 9 finished with value: 0.329162669870375 and parameters: {'model__n_estimators': 544, 'model__max_depth': 8, 'model__min_samples_split': 11, 'model__min_samples_leaf': 9, 'model__max_features': 'log2', 'pos_scale': 1.5374107423469834}. Best is trial 6 with value: 0.3776768642866365.
# [I 2026-02-10 20:50:21,925] Trial 10 finished with value: 0.38754445198636317 and parameters: {'model__n_estimators': 483, 'model__max_depth': 18, 'model__min_samples_split': 20, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.9531167090274952}. Best is trial 10 with value: 0.38754445198636317.
# [I 2026-02-10 20:50:43,177] Trial 11 finished with value: 0.38648364943250735 and parameters: {'model__n_estimators': 484, 'model__max_depth': 18, 'model__min_samples_split': 20, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.9073474201933382}. Best is trial 10 with value: 0.38754445198636317.
# [I 2026-02-10 20:51:01,635] Trial 12 finished with value: 0.3859477751001671 and parameters: {'model__n_estimators': 452, 'model__max_depth': 18, 'model__min_samples_split': 20, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.985382699482449}. Best is trial 10 with value: 0.38754445198636317.
# [I 2026-02-10 20:51:22,144] Trial 13 finished with value: 0.38825436782924794 and parameters: {'model__n_estimators': 473, 'model__max_depth': 18, 'model__min_samples_split': 19, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.4668368214169716}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:51:36,369] Trial 14 finished with value: 0.38295792097705034 and parameters: {'model__n_estimators': 392, 'model__max_depth': 16, 'model__min_samples_split': 17, 'model__min_samples_leaf': 6, 'model__max_features': 'log2', 'pos_scale': 1.3824101330244887}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:51:54,110] Trial 15 finished with value: 0.3737239730473715 and parameters: {'model__n_estimators': 471, 'model__max_depth': 16, 'model__min_samples_split': 18, 'model__min_samples_leaf': 13, 'model__max_features': 'log2', 'pos_scale': 1.626920764389904}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:52:12,355] Trial 16 finished with value: 0.3705245159680829 and parameters: {'model__n_estimators': 518, 'model__max_depth': 18, 'model__min_samples_split': 14, 'model__min_samples_leaf': 20, 'model__max_features': 'log2', 'pos_scale': 1.7469911502847375}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:52:36,308] Trial 17 finished with value: 0.3813653081583332 and parameters: {'model__n_estimators': 678, 'model__max_depth': 14, 'model__min_samples_split': 18, 'model__min_samples_leaf': 7, 'model__max_features': 'log2', 'pos_scale': 0.5181109127212766}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:52:50,284] Trial 18 finished with value: 0.3659641631631234 and parameters: {'model__n_estimators': 394, 'model__max_depth': 13, 'model__min_samples_split': 20, 'model__min_samples_leaf': 13, 'model__max_features': 'log2', 'pos_scale': 1.4594846227145382}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:53:08,861] Trial 19 finished with value: 0.3875773846242868 and parameters: {'model__n_estimators': 490, 'model__max_depth': 17, 'model__min_samples_split': 18, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.2400024662589695}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:53:33,454] Trial 20 finished with value: 0.37871058775507727 and parameters: {'model__n_estimators': 658, 'model__max_depth': 16, 'model__min_samples_split': 18, 'model__min_samples_leaf': 11, 'model__max_features': 'log2', 'pos_scale': 1.2010994122947818}. Best is trial 13 with value: 0.38825436782924794.
# [I 2026-02-10 20:53:54,165] Trial 21 finished with value: 0.38956569423498477 and parameters: {'model__n_estimators': 508, 'model__max_depth': 17, 'model__min_samples_split': 19, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 0.9787537479949556}. Best is trial 21 with value: 0.38956569423498477.
# [I 2026-02-10 20:54:17,528] Trial 22 finished with value: 0.3869354636554917 and parameters: {'model__n_estimators': 519, 'model__max_depth': 17, 'model__min_samples_split': 14, 'model__min_samples_leaf': 7, 'model__max_features': 'log2', 'pos_scale': 0.9216162501414481}. Best is trial 21 with value: 0.38956569423498477.
# [I 2026-02-10 20:54:38,344] Trial 23 finished with value: 0.37835049916523783 and parameters: {'model__n_estimators': 420, 'model__max_depth': 14, 'model__min_samples_split': 17, 'model__min_samples_leaf': 6, 'model__max_features': 'log2', 'pos_scale': 1.3004517997743372}. Best is trial 21 with value: 0.38956569423498477.
# [I 2026-02-10 21:20:20,105] Trial 24 finished with value: 0.38797776544632934 and parameters: {'model__n_estimators': 564, 'model__max_depth': 17, 'model__min_samples_split': 19, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 1.095428127433434}. Best is trial 21 with value: 0.38956569423498477.

# %%
import importlib
import thesis_code.data_analysis.ml_pipeline as ml_pipeline
importlib.reload(ml_pipeline)
# Out:
# <module 'thesis_code.data_analysis.ml_pipeline' from '/home/user_stel/project_thesis/thesis_code/data_analysis/ml_pipeline.py'>

# %%
best_params = study_rf.best_params.copy()
print("Best params:", best_params)

pos_scale = best_params.pop("pos_scale", None)

if pos_scale is not None:
    class_weights = {0: 1.0, 1: pos_scale}
else:
    class_weights = "balanced"


best_rf = rf_pipeline.set_params(
    **best_params,
    model__class_weight=class_weights
)
# Out:
# Best params: {'model__n_estimators': 508, 'model__max_depth': 17, 'model__min_samples_split': 19, 'model__min_samples_leaf': 5, 'model__max_features': 'log2', 'pos_scale': 0.9787537479949556}

# %%
ml_pipeline.save_model(best_rf, "rf_model")
# Out:
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/rf_model.joblib
# PosixPath('/home/user_stel/project_thesis/thesis_code/data_analysis/models/rf_model.joblib')

# %%
best_rf.get_params().keys() #sanity check
# Out:
# dict_keys(['memory', 'steps', 'transform_input', 'verbose', 'preprocess', 'model', 'preprocess__force_int_remainder_cols', 'preprocess__n_jobs', 'preprocess__remainder', 'preprocess__sparse_threshold', 'preprocess__transformer_weights', 'preprocess__transformers', 'preprocess__verbose', 'preprocess__verbose_feature_names_out', 'preprocess__num', 'preprocess__cat', 'preprocess__cat__categories', 'preprocess__cat__drop', 'preprocess__cat__dtype', 'preprocess__cat__feature_name_combiner', 'preprocess__cat__handle_unknown', 'preprocess__cat__max_categories', 'preprocess__cat__min_frequency', 'preprocess__cat__sparse_output', 'model__bootstrap', 'model__ccp_alpha', 'model__class_weight', 'model__criterion', 'model__max_depth', 'model__max_features', 'model__max_leaf_nodes', 'model__max_samples', 'model__min_impurity_decrease', 'model__min_samples_leaf', 'model__min_samples_split', 'model__min_weight_fraction_leaf', 'model__monotonic_cst', 'model__n_estimators', 'model__n_jobs', 'model__oob_score', 'model__random_state', 'model__verbose', 'model__warm_start'])

# %% [markdown]
# ### Logistic Regression

# %%
lr_pipeline = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("model", LogisticRegression(
            max_iter=1000,
            random_state=RANDOM_STATE
        ))
    ]
)

param_grid_lr = {
    "model__C": [0.01, 0.1, 1, 10],
    "model__penalty": ["l2"],
    "model__solver": ["lbfgs"]
}

class_weights_lr = calculate_class_weights(y_train)
lr_pipeline.set_params(model__class_weight=class_weights_lr)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['b_factor',
#                                                    'RSA_total_freesasa_tien',
#                                                    'density', 'n_neighbors',
#                                                    'neighbor_frac_exposed',
#                                                    'neighbor_frac_hydrophobic',
#                                                    'neighbor_frac_charged',
#                                                    'neighbor_frac_polar',
#                                                    'neighbor_frac_aromatic',
#                                                    'neighbor_frac_small',
#                                                    'neighbor_mean_RSA']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sec_struc',
#                                                    'sec_struc_full',
#                                                    'prot_block'])])),
#                 ('model',
#                  LogisticRegression(class_weight={np.int64(0): np.float64(0.5895831603037938),
#                                                   np.int64(1): np.float64(3.290703064640742)},
#                                     max_iter=1000, random_state=42))])

# %%
grid_lr = GridSearchCV(
    estimator=lr_pipeline,     
    param_grid=param_grid_lr,
    scoring="average_precision",
    cv=3,
    n_jobs=-1,
    error_score="raise"        
)

grid_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          'passthrough',
#                                                                          ['b_factor',
#                                                                           'RSA_total_freesasa_tien',
#                                                                           'density',
#                                                                           'n_neighbors',
#                                                                           'neighbor_frac_exposed',
#                                                                           'neighbor_frac_hydrophobic',
#                                                                           'neighbor_frac_charged',
#                                                                           'neighbor_frac_polar',
#                                                                           'neighbor_frac_aromatic',
#                                                                           'neighbor_frac_small',
#                                                                           'neighbor_me...
#                                                                                        sparse_output=False),
#                                                                          ['sec_struc',
#                                                                           'sec_struc_full',
#                                                                           'prot_block'])])),
#                                        ('model',
#                                         LogisticRegression(class_weight={np.int64(0): np.float64(0.5895831603037938),
#                                                                          np.int64(1): np.float64(3.290703064640742)},
#                                                            max_iter=1000,
#                                                            random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model__C': [0.01, 0.1, 1, 10],
#                          'model__penalty': ['l2'], 'model__solver': ['lbfgs']},
#              scoring='average_precision')

# %%
best_lr = grid_lr.best_estimator_
print(grid_lr.best_params_)
# Out:
# {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}

# %%
ml_pipeline.save_model(best_lr, "lr_model")
# Out:
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/lr_model.joblib
# PosixPath('/home/user_stel/project_thesis/thesis_code/data_analysis/models/lr_model.joblib')

# %% [markdown]
# ### Support Vector Machines

# %%
preprocessor_svm = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_cols),
        ("num", StandardScaler(), numeric_cols),
    ],
    remainder="drop"
)

# %%
svm_pipeline = Pipeline([
    ("preprocess", preprocessor_svm),  # with StandardScaler
    ("model", SVC(class_weight="balanced", max_iter=5000))])

# %%
param_grid_svm = {
    "model__C": [0.1, 1, 10]
    # "model__gamma": ["scale", "auto"]
}

class_weights_svm = calculate_class_weights(y_train)

svm_pipeline.set_params(
    model__class_weight=class_weights_svm
)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sec_struc',
#                                                    'sec_struc_full',
#                                                    'prot_block']),
#                                                  ('num', StandardScaler(),
#                                                   ['b_factor',
#                                                    'RSA_total_freesasa_tien',
#                                                    'density', 'n_neighbors',
#                                                    'neighbor_frac_exposed',
#                                                    'neighbor_frac_hydrophobic',
#                                                    'neighbor_frac_charged',
#                                                    'neighbor_frac_polar',
#                                                    'neighbor_frac_aromatic',
#                                                    'neighbor_frac_small',
#                                                    'neighbor_mean_RSA'])])),
#                 ('model',
#                  SVC(class_weight={np.int64(0): np.float64(0.5895831603037938),
#                                    np.int64(1): np.float64(3.290703064640742)},
#                      max_iter=5000))])

# %%
grid_svm = GridSearchCV(
    estimator=svm_pipeline,        
    param_grid=param_grid_svm,
    scoring="average_precision",
    cv=3,
    n_jobs=-1,
    error_score="raise"
)

grid_svm.fit(X_train, y_train)
# Out:
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# GridSearchCV(cv=3, error_score='raise',
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['sec_struc',
#                                                                           'sec_struc_full',
#                                                                           'prot_block']),
#                                                                         ('num',
#                                                                          StandardScaler(),
#                                                                          ['b_factor',
#                                                                           'RSA_total_freesasa_tien',
#                                                                           'density',
#                                                                           'n_neighbors',
#                                                                           'neighbor_frac_exposed',
#                                                                           'neighbor_frac_hydrophobic',
#                                                                           'neighbor_frac_charged',
#                                                                           'neighbor_frac_polar',
#                                                                           'neighbor_frac_aromatic',
#                                                                           'neighbor_frac_small',
#                                                                           'neighbor_mean_RSA'])])),
#                                        ('model',
#                                         SVC(class_weight={np.int64(0): np.float64(0.5895831603037938),
#                                                           np.int64(1): np.float64(3.290703064640742)},
#                                             max_iter=5000))]),
#              n_jobs=-1, param_grid={'model__C': [0.1, 1, 10]},
#              scoring='average_precision')

# %%
best_svm = grid_svm.best_estimator_
print(grid_svm.best_params_)
# Out:
# {'model__C': 0.1}

# %%
ml_pipeline.save_model(best_svm, "svm_model")
# Out:
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/svm_model.joblib
# PosixPath('/home/user_stel/project_thesis/thesis_code/data_analysis/models/svm_model.joblib')

# %% [markdown]
# ### XGBoost

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("model", XGBClassifier(
            objective="binary:logistic",
            eval_metric="logloss",
            use_label_encoder=False,
            random_state=RANDOM_STATE,
            n_jobs=-1
        ))
    ]
)

# %%
def xgb_objective(trial):

    params = {
        "model__n_estimators": trial.suggest_int("model__n_estimators", 200, 800),
        "model__max_depth": trial.suggest_int("model__max_depth", 3, 10),
        "model__learning_rate": trial.suggest_float(
            "model__learning_rate", 0.01, 0.2, log=True
        ),
        "model__subsample": trial.suggest_float("model__subsample", 0.6, 1.0),
        "model__colsample_bytree": trial.suggest_float(
            "model__colsample_bytree", 0.6, 1.0
        ),
        "model__min_child_weight": trial.suggest_int(
            "model__min_child_weight", 1, 10
        ),
        "model__reg_lambda": trial.suggest_float(
            "model__reg_lambda", 1e-3, 10.0, log=True
        )
    }

    model = xgb_pipeline.set_params(**params)

    class_weights = calculate_class_weights(y_train)
    scale_pos_weight = class_weights[1] / class_weights[0]

    model.set_params(model__scale_pos_weight=scale_pos_weight)

    model.fit(X_train, y_train)

    y_val_proba = model.predict_proba(X_val)[:, 1]
    return average_precision_score(y_val, y_val_proba)

# %%
study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(xgb_objective, n_trials=50)
# Out:
# [I 2026-01-18 20:00:28,653] A new study created in memory with name: no-name-610eb82a-544b-4caf-8bc5-6063a44af79e
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:00:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:00:44,644] Trial 0 finished with value: 0.3856020086821153 and parameters: {'model__n_estimators': 251, 'model__max_depth': 10, 'model__learning_rate': 0.051889669620576284, 'model__subsample': 0.9112738881725808, 'model__colsample_bytree': 0.9080899900103306, 'model__min_child_weight': 6, 'model__reg_lambda': 0.017218037079039197}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:00:45] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:00:58,822] Trial 1 finished with value: 0.37413816419375345 and parameters: {'model__n_estimators': 704, 'model__max_depth': 4, 'model__learning_rate': 0.18118827541260477, 'model__subsample': 0.9981727970595841, 'model__colsample_bytree': 0.9732532230386381, 'model__min_child_weight': 6, 'model__reg_lambda': 0.08104623663661369}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:00:59] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:05,909] Trial 2 finished with value: 0.3769563600799887 and parameters: {'model__n_estimators': 285, 'model__max_depth': 7, 'model__learning_rate': 0.08554638538944635, 'model__subsample': 0.9978228495789992, 'model__colsample_bytree': 0.9458918141857997, 'model__min_child_weight': 1, 'model__reg_lambda': 0.18479640819054355}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:06] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:10,509] Trial 3 finished with value: 0.37577292804390566 and parameters: {'model__n_estimators': 448, 'model__max_depth': 6, 'model__learning_rate': 0.11153432023529954, 'model__subsample': 0.7528062198987904, 'model__colsample_bytree': 0.6997177539586793, 'model__min_child_weight': 3, 'model__reg_lambda': 0.011863281672944473}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:17,539] Trial 4 finished with value: 0.36124687601848937 and parameters: {'model__n_estimators': 497, 'model__max_depth': 7, 'model__learning_rate': 0.17470657918958574, 'model__subsample': 0.810336078232466, 'model__colsample_bytree': 0.9093404512317284, 'model__min_child_weight': 6, 'model__reg_lambda': 0.016952741636736327}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:17] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:30,371] Trial 5 finished with value: 0.3851291948964617 and parameters: {'model__n_estimators': 659, 'model__max_depth': 10, 'model__learning_rate': 0.01722488481690315, 'model__subsample': 0.9594488079533066, 'model__colsample_bytree': 0.6602209271613344, 'model__min_child_weight': 9, 'model__reg_lambda': 7.137337992668615}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:36,187] Trial 6 finished with value: 0.38092609011173983 and parameters: {'model__n_estimators': 559, 'model__max_depth': 7, 'model__learning_rate': 0.09217136678921262, 'model__subsample': 0.9236495531570503, 'model__colsample_bytree': 0.6143612564759533, 'model__min_child_weight': 3, 'model__reg_lambda': 0.0015451261856580752}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:36] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:43,972] Trial 7 finished with value: 0.3582929562035931 and parameters: {'model__n_estimators': 503, 'model__max_depth': 8, 'model__learning_rate': 0.15911026603322595, 'model__subsample': 0.7606657599514889, 'model__colsample_bytree': 0.891574105511808, 'model__min_child_weight': 10, 'model__reg_lambda': 0.04200248918235867}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:50,113] Trial 8 finished with value: 0.3684373478074807 and parameters: {'model__n_estimators': 322, 'model__max_depth': 8, 'model__learning_rate': 0.011242775055788063, 'model__subsample': 0.8441397592832639, 'model__colsample_bytree': 0.9327409410981127, 'model__min_child_weight': 10, 'model__reg_lambda': 2.024373877480322}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:51,869] Trial 9 finished with value: 0.3428508606806955 and parameters: {'model__n_estimators': 218, 'model__max_depth': 3, 'model__learning_rate': 0.07402169336457358, 'model__subsample': 0.7330631839165214, 'model__colsample_bytree': 0.6332368977713564, 'model__min_child_weight': 9, 'model__reg_lambda': 0.03674651503712524}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:01:58,313] Trial 10 finished with value: 0.3809562997567184 and parameters: {'model__n_estimators': 362, 'model__max_depth': 10, 'model__learning_rate': 0.04658079448765683, 'model__subsample': 0.6584979583090685, 'model__colsample_bytree': 0.8199753463694068, 'model__min_child_weight': 7, 'model__reg_lambda': 0.0014947859279286582}. Best is trial 0 with value: 0.3856020086821153.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:01:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:02:13,451] Trial 11 finished with value: 0.3872475915453589 and parameters: {'model__n_estimators': 790, 'model__max_depth': 10, 'model__learning_rate': 0.017363169712654045, 'model__subsample': 0.9018909745991077, 'model__colsample_bytree': 0.7553813232827492, 'model__min_child_weight': 8, 'model__reg_lambda': 8.25707007943272}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:02:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:02:25,134] Trial 12 finished with value: 0.3863764272566881 and parameters: {'model__n_estimators': 741, 'model__max_depth': 9, 'model__learning_rate': 0.02668732770157333, 'model__subsample': 0.8991654577253086, 'model__colsample_bytree': 0.7596191385551756, 'model__min_child_weight': 8, 'model__reg_lambda': 0.4737590068700892}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:02:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:02:37,212] Trial 13 finished with value: 0.38608397503746034 and parameters: {'model__n_estimators': 753, 'model__max_depth': 9, 'model__learning_rate': 0.024386581991054288, 'model__subsample': 0.8664926357974696, 'model__colsample_bytree': 0.7506007227775078, 'model__min_child_weight': 8, 'model__reg_lambda': 0.7745400421032088}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:02:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:02:49,627] Trial 14 finished with value: 0.38568044019951064 and parameters: {'model__n_estimators': 796, 'model__max_depth': 9, 'model__learning_rate': 0.027586627475714807, 'model__subsample': 0.8891126195244221, 'model__colsample_bytree': 0.8026000928892775, 'model__min_child_weight': 8, 'model__reg_lambda': 8.896736539695718}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:02:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:02:54,901] Trial 15 finished with value: 0.3687271458133452 and parameters: {'model__n_estimators': 638, 'model__max_depth': 5, 'model__learning_rate': 0.028822729089006367, 'model__subsample': 0.8179892807811635, 'model__colsample_bytree': 0.7321383045914305, 'model__min_child_weight': 4, 'model__reg_lambda': 0.6194818332488846}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:02:55] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:03:12,251] Trial 16 finished with value: 0.384056376620206 and parameters: {'model__n_estimators': 797, 'model__max_depth': 9, 'model__learning_rate': 0.012146843989673894, 'model__subsample': 0.9434039414477378, 'model__colsample_bytree': 0.8445049163169401, 'model__min_child_weight': 8, 'model__reg_lambda': 2.1490062880224037}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:03:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:03:22,001] Trial 17 finished with value: 0.3813968406879369 and parameters: {'model__n_estimators': 606, 'model__max_depth': 8, 'model__learning_rate': 0.018344550070930863, 'model__subsample': 0.8740350754754195, 'model__colsample_bytree': 0.7613999879682154, 'model__min_child_weight': 5, 'model__reg_lambda': 0.578420784719145}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:03:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:03:33,391] Trial 18 finished with value: 0.3821093214876933 and parameters: {'model__n_estimators': 702, 'model__max_depth': 9, 'model__learning_rate': 0.038342441964154074, 'model__subsample': 0.8484764850826053, 'model__colsample_bytree': 0.6964957447336959, 'model__min_child_weight': 7, 'model__reg_lambda': 2.922826583214728}. Best is trial 11 with value: 0.3872475915453589.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:03:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:03:46,525] Trial 19 finished with value: 0.38727133967426003 and parameters: {'model__n_estimators': 736, 'model__max_depth': 10, 'model__learning_rate': 0.01648112974511485, 'model__subsample': 0.6798832125171336, 'model__colsample_bytree': 0.8521992621276581, 'model__min_child_weight': 9, 'model__reg_lambda': 0.14738782055379776}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:03:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:03:52,308] Trial 20 finished with value: 0.36938184676464336 and parameters: {'model__n_estimators': 581, 'model__max_depth': 6, 'model__learning_rate': 0.01546284113936435, 'model__subsample': 0.6406383646043114, 'model__colsample_bytree': 0.8573748964164838, 'model__min_child_weight': 9, 'model__reg_lambda': 0.005629514027870776}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:03:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:04:20,458] Trial 21 finished with value: 0.38604837192726393 and parameters: {'model__n_estimators': 720, 'model__max_depth': 10, 'model__learning_rate': 0.02123149553832065, 'model__subsample': 0.6886875453683152, 'model__colsample_bytree': 0.7823616247919997, 'model__min_child_weight': 7, 'model__reg_lambda': 0.1941020737779551}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:04:20] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:04:36,409] Trial 22 finished with value: 0.3768748605962621 and parameters: {'model__n_estimators': 741, 'model__max_depth': 10, 'model__learning_rate': 0.034238052070227606, 'model__subsample': 0.6090884559891769, 'model__colsample_bytree': 0.8372239554291363, 'model__min_child_weight': 10, 'model__reg_lambda': 0.27203748541565814}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:04:36] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:04:47,640] Trial 23 finished with value: 0.3798399951913192 and parameters: {'model__n_estimators': 668, 'model__max_depth': 9, 'model__learning_rate': 0.010101570775469785, 'model__subsample': 0.7907155817630812, 'model__colsample_bytree': 0.7159234835232806, 'model__min_child_weight': 8, 'model__reg_lambda': 0.9384411579540655}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:04:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:04:58,797] Trial 24 finished with value: 0.3810820045367661 and parameters: {'model__n_estimators': 800, 'model__max_depth': 8, 'model__learning_rate': 0.015157902933839265, 'model__subsample': 0.715726024749158, 'model__colsample_bytree': 0.7828748468730664, 'model__min_child_weight': 9, 'model__reg_lambda': 0.08502377605053756}. Best is trial 19 with value: 0.38727133967426003.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:04:59] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:05:12,255] Trial 25 finished with value: 0.3879742023212467 and parameters: {'model__n_estimators': 759, 'model__max_depth': 10, 'model__learning_rate': 0.01323084356551085, 'model__subsample': 0.8971857262596246, 'model__colsample_bytree': 0.8626199585459593, 'model__min_child_weight': 7, 'model__reg_lambda': 0.30385885542295415}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:05:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:05:24,240] Trial 26 finished with value: 0.38541737074098303 and parameters: {'model__n_estimators': 627, 'model__max_depth': 10, 'model__learning_rate': 0.013063748406747401, 'model__subsample': 0.9542373873453651, 'model__colsample_bytree': 0.8723854995850955, 'model__min_child_weight': 5, 'model__reg_lambda': 5.0960739100144155}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:05:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:05:39,840] Trial 27 finished with value: 0.38692265141371784 and parameters: {'model__n_estimators': 674, 'model__max_depth': 10, 'model__learning_rate': 0.020102890633132683, 'model__subsample': 0.7727583878424014, 'model__colsample_bytree': 0.993522890501104, 'model__min_child_weight': 7, 'model__reg_lambda': 1.434575613077017}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:05:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:05:50,501] Trial 28 finished with value: 0.38021391395071735 and parameters: {'model__n_estimators': 760, 'model__max_depth': 8, 'model__learning_rate': 0.013998495467687163, 'model__subsample': 0.6012535396459383, 'model__colsample_bytree': 0.8087806122557544, 'model__min_child_weight': 9, 'model__reg_lambda': 0.04380211913247827}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:05:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:05:58,627] Trial 29 finished with value: 0.3788980161083443 and parameters: {'model__n_estimators': 406, 'model__max_depth': 10, 'model__learning_rate': 0.06199511731118451, 'model__subsample': 0.9195093544082693, 'model__colsample_bytree': 0.8821298316173289, 'model__min_child_weight': 6, 'model__reg_lambda': 0.004072725091129872}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:05:59] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:06:06,435] Trial 30 finished with value: 0.38442526629366336 and parameters: {'model__n_estimators': 538, 'model__max_depth': 9, 'model__learning_rate': 0.03542141922402371, 'model__subsample': 0.8398874822401713, 'model__colsample_bytree': 0.915775222188922, 'model__min_child_weight': 7, 'model__reg_lambda': 4.422601222528859}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:06:06] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:06:19,637] Trial 31 finished with value: 0.38745313030843653 and parameters: {'model__n_estimators': 697, 'model__max_depth': 10, 'model__learning_rate': 0.019743210410017507, 'model__subsample': 0.779585494333593, 'model__colsample_bytree': 0.9519009264883588, 'model__min_child_weight': 7, 'model__reg_lambda': 1.3875891711200155}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:06:20] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:06:35,548] Trial 32 finished with value: 0.3861637599338824 and parameters: {'model__n_estimators': 697, 'model__max_depth': 10, 'model__learning_rate': 0.022660465485461998, 'model__subsample': 0.6672394774508809, 'model__colsample_bytree': 0.9531221726655901, 'model__min_child_weight': 7, 'model__reg_lambda': 0.25780849346645535}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:06:35] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:06:48,854] Trial 33 finished with value: 0.38643112098510624 and parameters: {'model__n_estimators': 763, 'model__max_depth': 10, 'model__learning_rate': 0.01652009627630959, 'model__subsample': 0.9765608574339211, 'model__colsample_bytree': 0.9556428513913884, 'model__min_child_weight': 5, 'model__reg_lambda': 0.11636087712396323}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:06:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:01,124] Trial 34 finished with value: 0.3840243185726748 and parameters: {'model__n_estimators': 712, 'model__max_depth': 9, 'model__learning_rate': 0.010220160178065494, 'model__subsample': 0.7176536706745761, 'model__colsample_bytree': 0.9847315992995502, 'model__min_child_weight': 6, 'model__reg_lambda': 0.42079637824376914}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:19,862] Trial 35 finished with value: 0.38607119188817624 and parameters: {'model__n_estimators': 774, 'model__max_depth': 9, 'model__learning_rate': 0.01330601785529871, 'model__subsample': 0.7803403611726251, 'model__colsample_bytree': 0.9250459625977625, 'model__min_child_weight': 1, 'model__reg_lambda': 1.3119630010788061}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:20] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:23,988] Trial 36 finished with value: 0.34331020135962287 and parameters: {'model__n_estimators': 688, 'model__max_depth': 3, 'model__learning_rate': 0.01968813382175821, 'model__subsample': 0.8059376305060133, 'model__colsample_bytree': 0.829507933400728, 'model__min_child_weight': 8, 'model__reg_lambda': 3.664707949457752}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:31,032] Trial 37 finished with value: 0.3690490028175829 and parameters: {'model__n_estimators': 729, 'model__max_depth': 5, 'model__learning_rate': 0.01829800736864946, 'model__subsample': 0.932481426444089, 'model__colsample_bytree': 0.8997524377639973, 'model__min_child_weight': 6, 'model__reg_lambda': 0.10401895952710642}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:41,693] Trial 38 finished with value: 0.38253771462392183 and parameters: {'model__n_estimators': 649, 'model__max_depth': 10, 'model__learning_rate': 0.03080549625035505, 'model__subsample': 0.9877470390486744, 'model__colsample_bytree': 0.860556952184097, 'model__min_child_weight': 9, 'model__reg_lambda': 0.32185722319793586}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:07:48,480] Trial 39 finished with value: 0.37878440285658843 and parameters: {'model__n_estimators': 590, 'model__max_depth': 7, 'model__learning_rate': 0.023474148158326304, 'model__subsample': 0.7486001676801242, 'model__colsample_bytree': 0.9677242139090569, 'model__min_child_weight': 10, 'model__reg_lambda': 0.14815606273018805}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:07:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:08:03,620] Trial 40 finished with value: 0.3833058570820169 and parameters: {'model__n_estimators': 776, 'model__max_depth': 8, 'model__learning_rate': 0.015240738489712566, 'model__subsample': 0.8252896672825665, 'model__colsample_bytree': 0.8934776060705526, 'model__min_child_weight': 8, 'model__reg_lambda': 0.058095621350166764}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:08:04] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:08:15,846] Trial 41 finished with value: 0.38630741540611313 and parameters: {'model__n_estimators': 666, 'model__max_depth': 10, 'model__learning_rate': 0.020120156743520613, 'model__subsample': 0.7754268405717488, 'model__colsample_bytree': 0.9962358641443587, 'model__min_child_weight': 7, 'model__reg_lambda': 1.3796642409818416}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:08:16] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:08:29,225] Trial 42 finished with value: 0.3861784160229321 and parameters: {'model__n_estimators': 682, 'model__max_depth': 10, 'model__learning_rate': 0.011887847492260852, 'model__subsample': 0.6961641990943139, 'model__colsample_bytree': 0.9774467535590442, 'model__min_child_weight': 7, 'model__reg_lambda': 1.4388354957408884}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:08:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:08:42,348] Trial 43 finished with value: 0.3850766771446844 and parameters: {'model__n_estimators': 720, 'model__max_depth': 10, 'model__learning_rate': 0.01738766518837341, 'model__subsample': 0.7643221326810669, 'model__colsample_bytree': 0.943252551189072, 'model__min_child_weight': 6, 'model__reg_lambda': 7.272730492388371}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:08:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:08:51,986] Trial 44 finished with value: 0.385317605126116 and parameters: {'model__n_estimators': 622, 'model__max_depth': 9, 'model__learning_rate': 0.024663047275877144, 'model__subsample': 0.89650418296173, 'model__colsample_bytree': 0.9962373962058197, 'model__min_child_weight': 9, 'model__reg_lambda': 2.4004469736989957}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:08:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:09:01,489] Trial 45 finished with value: 0.3835903938574741 and parameters: {'model__n_estimators': 512, 'model__max_depth': 10, 'model__learning_rate': 0.04177252038348682, 'model__subsample': 0.7447717474273072, 'model__colsample_bytree': 0.6756968796612945, 'model__min_child_weight': 8, 'model__reg_lambda': 0.9772892128462617}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:09:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:09:13,874] Trial 46 finished with value: 0.383770390630665 and parameters: {'model__n_estimators': 741, 'model__max_depth': 9, 'model__learning_rate': 0.01347329530506706, 'model__subsample': 0.7953181319605389, 'model__colsample_bytree': 0.9668825829054546, 'model__min_child_weight': 7, 'model__reg_lambda': 5.760753859337812}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:09:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:09:23,211] Trial 47 finished with value: 0.3878931871266832 and parameters: {'model__n_estimators': 452, 'model__max_depth': 10, 'model__learning_rate': 0.021200852415193643, 'model__subsample': 0.8641391183559614, 'model__colsample_bytree': 0.9346171208923265, 'model__min_child_weight': 4, 'model__reg_lambda': 0.022931226696182704}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:09:23] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:09:30,097] Trial 48 finished with value: 0.35729866860441495 and parameters: {'model__n_estimators': 459, 'model__max_depth': 9, 'model__learning_rate': 0.12561888184724032, 'model__subsample': 0.8606552005825786, 'model__colsample_bytree': 0.9287204032765372, 'model__min_child_weight': 3, 'model__reg_lambda': 0.023557157230320522}. Best is trial 25 with value: 0.3879742023212467.
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [20:09:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-01-18 20:09:34,742] Trial 49 finished with value: 0.363374000969473 and parameters: {'model__n_estimators': 439, 'model__max_depth': 4, 'model__learning_rate': 0.048964293020620754, 'model__subsample': 0.8805160882298482, 'model__colsample_bytree': 0.9082446632875655, 'model__min_child_weight': 4, 'model__reg_lambda': 0.010474841772685902}. Best is trial 25 with value: 0.3879742023212467.

# %%
best_xgb = xgb_pipeline.set_params(**study_xgb.best_params)
print(study_xgb.best_params)
# Out:
# {'model__n_estimators': 759, 'model__max_depth': 10, 'model__learning_rate': 0.01323084356551085, 'model__subsample': 0.8971857262596246, 'model__colsample_bytree': 0.8626199585459593, 'model__min_child_weight': 7, 'model__reg_lambda': 0.30385885542295415}

# %%
ml_pipeline.save_model(best_xgb, "xgb_model")
# Out:
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/xgb_model.joblib
# /home/user_stel/miniconda3/lib/python3.12/pickle.py:572: UserWarning: [20:09:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   rv = reduce(self.proto)
# PosixPath('/home/user_stel/project_thesis/thesis_code/data_analysis/models/xgb_model.joblib')

# %% [markdown]
# ### LightGBM

# %%
lgb_pipeline = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("model", LGBMClassifier(
            objective="binary",
            random_state=RANDOM_STATE,
            n_jobs=-1
        ))
    ]
)

# %%
def lgb_objective(trial):

    params = {
        "model__n_estimators": trial.suggest_int("model__n_estimators", 200, 800),
        "model__learning_rate": trial.suggest_float(
            "model__learning_rate", 0.01, 0.2, log=True
        ),
        "model__max_depth": trial.suggest_int("model__max_depth", 3, 12),
        "model__num_leaves": trial.suggest_int("model__num_leaves", 15, 255),
        "model__subsample": trial.suggest_float("model__subsample", 0.6, 1.0),
        "model__colsample_bytree": trial.suggest_float(
            "model__colsample_bytree", 0.6, 1.0
        ),
        "model__min_child_samples": trial.suggest_int(
            "model__min_child_samples", 10, 50
        )
    }

    model = lgb_pipeline.set_params(**params)

    # handle class imbalance via class_weight
    class_weights = calculate_class_weights(y_train)
    model.set_params(model__class_weight=class_weights)

    model.fit(X_train, y_train)

    y_val_proba = model.predict_proba(X_val)[:, 1]
    return average_precision_score(y_val, y_val_proba)

# %%
study_lgb = optuna.create_study(direction="maximize")
study_lgb.optimize(lgb_objective, n_trials=50)

print(study_lgb.best_params)
# Out:
# [I 2026-01-18 20:15:05,072] A new study created in memory with name: no-name-2d1ba957-0e59-4335-a022-955f87726ba3
# [LightGBM] [Info] Number of positive: 19415, number of negative: 108363
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 127778, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-01-18 20:15:33,852] Trial 0 finished with value: 0.38106566798480235 and parameters: {'model__n_estimators': 671, 'model__learning_rate': 0.041641667365313814, 'model__max_depth': 10, 'model__num_leaves': 199, 'model__subsample': 0.6972240621035143, 'model__colsample_bytree': 0.8160367831315182, 'model__min_child_samples': 11}. Best is trial 0 with value: 0.38106566798480235.
# [LightGBM] [Info] Number of positive: 19415, number of negative: 108363
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011431 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 127778, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-01-18 20:21:26,040] Trial 48 finished with value: 0.3774563296371744 and parameters: {'model__n_estimators': 401, 'model__learning_rate': 0.08945457866679903, 'model__max_depth': 12, 'model__num_leaves': 197, 'model__subsample': 0.9815852894548082, 'model__colsample_bytree': 0.6153101032880338, 'model__min_child_samples': 36}. Best is trial 35 with value: 0.38721251256450995.
# [LightGBM] [Info] Number of positive: 19415, number of negative: 108363
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 127778, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-01-18 20:21:33,508] Trial 49 finished with value: 0.3821840945478919 and parameters: {'model__n_estimators': 347, 'model__learning_rate': 0.022820077888829567, 'model__max_depth': 10, 'model__num_leaves': 143, 'model__subsample': 0.8413059970700424, 'model__colsample_bytree': 0.6713384130746967, 'model__min_child_samples': 26}. Best is trial 35 with value: 0.38721251256450995.
# {'model__n_estimators': 411, 'model__learning_rate': 0.04900847530563631, 'model__max_depth': 12, 'model__num_leaves': 152, 'model__subsample': 0.721455577062599, 'model__colsample_bytree': 0.6812661281747796, 'model__min_child_samples': 30}

# %%
best_lgb = lgb_pipeline.set_params(**study_lgb.best_params)
print(study_lgb.best_params)
# Out:
# {'model__n_estimators': 411, 'model__learning_rate': 0.04900847530563631, 'model__max_depth': 12, 'model__num_leaves': 152, 'model__subsample': 0.721455577062599, 'model__colsample_bytree': 0.6812661281747796, 'model__min_child_samples': 30}

# %%
ml_pipeline.save_model(best_lgb, "lgb_model")
# Out:
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/lgb_model.joblib
# PosixPath('/home/user_stel/project_thesis/thesis_code/data_analysis/models/lgb_model.joblib')

# %% [markdown]
# # Training on train+val

# %%
# Load all models
models = {
    "rf":  load_model("rf_model"),
    "lr":  load_model("lr_model"),
    "svm": load_model("svm_model"),
    "xgb": load_model("xgb_model"),
    "lgb": load_model("lgb_model")
}

# %%
# Prepare combined train+val set
X_trainval = pd.concat([X_train, X_val])
y_trainval = pd.concat([y_train, y_val])

# %%
final_results = {}

for name, model in models.items():

    clf = model.named_steps["model"]

    # -----------------------------
    # Handle class imbalance
    # -----------------------------
    if hasattr(clf, "class_weight"):
        class_weights = calculate_class_weights(y_trainval)
        model.set_params(model__class_weight=class_weights)

    elif hasattr(clf, "scale_pos_weight"):
        class_weights = calculate_class_weights(y_trainval)
        scale_pos_weight = class_weights[1] / class_weights[0]
        model.set_params(model__scale_pos_weight=scale_pos_weight)

    # -----------------------------
    # Retrain on train + val
    # -----------------------------
    model.fit(X_trainval, y_trainval)

    # -----------------------------
    # Evaluate on test (ONCE)
    # -----------------------------
    metrics = evaluate_model(
        model,
        X_test,
        y_test,
        split_name=f"{name.upper()} – Final Test"
    )

    final_results[name] = metrics

    # -----------------------------
    # Save final model
    # -----------------------------
    save_model(model, f"{name}_final")
# Out:
# ===== RF – Final Test evaluation =====
#               precision    recall  f1-score   support
#
#            0      0.922     0.757     0.832     23221
#            1      0.330     0.651     0.438      4270
#
#     accuracy                          0.741     27491
#    macro avg      0.626     0.704     0.635     27491
# weighted avg      0.830     0.741     0.770     27491
#
# Confusion matrix:
# [[17585  5636]
#  [ 1489  2781]]
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/rf_final.joblib
#
# ===== LR – Final Test evaluation =====
#               precision    recall  f1-score   support
#
#            0      0.927     0.638     0.756     23221
#            1      0.270     0.728     0.394      4270
#
#     accuracy                          0.652     27491
#    macro avg      0.599     0.683     0.575     27491
# weighted avg      0.825     0.652     0.700     27491
#
# Confusion matrix:
# [[14816  8405]
#  [ 1161  3109]]
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/lr_final.joblib
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ===== SVM – Final Test evaluation =====
#               precision    recall  f1-score   support
#
#            0      0.845     1.000     0.916     23221
#            1      0.000     0.000     0.000      4270
#
#     accuracy                          0.845     27491
#    macro avg      0.422     0.500     0.458     27491
# weighted avg      0.713     0.845     0.774     27491
#
# Confusion matrix:
# [[23221     0]
#  [ 4270     0]]
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/svm_final.joblib
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user_stel/miniconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:42:03] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ===== XGB – Final Test evaluation =====
#               precision    recall  f1-score   support
#
#            0      0.933     0.681     0.788     23221
#            1      0.298     0.734     0.423      4270
#
#     accuracy                          0.690     27491
#    macro avg      0.615     0.708     0.606     27491
# weighted avg      0.834     0.690     0.731     27491
#
# Confusion matrix:
# [[15822  7399]
#  [ 1136  3134]]
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/xgb_final.joblib
# [LightGBM] [Info] Number of positive: 23613, number of negative: 132786
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012523 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 156399, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/user_stel/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ===== LGB – Final Test evaluation =====
#               precision    recall  f1-score   support
#
#            0      0.932     0.688     0.791     23221
#            1      0.300     0.726     0.424      4270
#
#     accuracy                          0.694     27491
#    macro avg      0.616     0.707     0.608     27491
# weighted avg      0.834     0.694     0.734     27491
#
# Confusion matrix:
# [[15975  7246]
#  [ 1171  3099]]
# Model saved to: /home/user_stel/project_thesis/thesis_code/data_analysis/models/lgb_final.joblib

# %%
results_df = (
    pd.DataFrame(final_results)
    .T
    .rename_axis("model")
    .reset_index()
)

results_df
# Out:
#   model  average_precision       mcc
# 0    rf           0.428502  0.321091
# 1    lr           0.311919  0.268812
# 2   svm           0.155324  0.000000
# 3   xgb           0.418933  0.309441
# 4   lgb           0.414107  0.309321

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

for name, model in models.items():
    y_score = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_score)
    plt.plot(recall, precision, label=name)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("Precision–Recall curves (test set)")
plt.show()

# %% [markdown]
# # Model Eavluation

# %%
models = {
    "RandomForest": best_rf,
    "LogisticRegression": best_lr,
    "SVM": best_svm,
    "XGBoost": best_xgb,
    "LightGBM": best_lgb
}

results = {}

for name, model in models.items():
    results[name] = evaluate_model(
        model,
        X_test,
        y_test,
        split_name=f"{name} – Test"
    )
